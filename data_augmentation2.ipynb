# %%
import pandas as pd
import os
from PIL import Image

# ============================================================================
# CATEGORIZATION OF ALL 35 PERSONAL PHOTOS
# ============================================================================

personal_photos_data = [
    # === BATCH 1: First set of images ===
    {'original_name': '60003.JPEG', 'category': 'Shirts', 'color': 'Navy Blue', 'description': 'Dark blue shirt outdoor setting'},
    {'original_name': '60008.JPEG', 'category': 'Shirts', 'color': 'Red', 'description': 'Ralph Lauren classic fit red shirt outdoor'},
    {'original_name': '60009.JPEG', 'category': 'Jeans', 'color': 'Blue', 'description': 'Ralph Lauren classic fit red shirt with UNIQLO skinny fit jeans outdoor'},
    {'original_name': '60004.JPEG', 'category': 'Shirts', 'color': 'Checkered', 'description': 'Checkered pattern shirt indoor'},
    {'original_name': '60007.JPEG', 'category': 'Jeans', 'color': 'Blue', 'description': 'Blue UNIQLO skinny fit jeans'},
    {'original_name': '60011.JPEG', 'category': 'Trousers', 'color': 'Black', 'description': 'Black trousers detailed'},
    {'original_name': '60005.JPEG', 'category': 'Jackets', 'color': 'Dark Grey', 'description': 'Dark grey UNIQLO reversible parka'},
    {'original_name': '60006.JPEG', 'category': 'Tshirts', 'color': 'Maroon', 'description': 'Tokyo City graphite t-shirt'},
    {'original_name': '60010.JPEG', 'category': 'Shirts', 'color': 'Striped', 'description': 'Blue striped shirt'},
    
    # === BATCH 2: Second set of images ===
    {'original_name': '60018.JPEG', 'category': 'Sweatshirts', 'color': 'Pink', 'description': 'Pink UNIQLO Crew Neck Sweatshirt'},
    {'original_name': '60014.JPEG', 'category': 'Tshirts', 'color': 'Pink', 'description': 'Pink polo shirt beach outdoor'},
    {'original_name': '60016.JPEG', 'category': 'Casual Shoes', 'color': 'Grey', 'description': 'Grey slip-on casual shoes'},
    {'original_name': '60001.JPG', 'category': 'Jackets', 'color': 'Brown', 'description': 'Brown Corduroy Jacket'},
    {'original_name': '60015.JPEG', 'category': 'Shorts', 'color': 'Blue', 'description': 'Blue UNIQLO Chino Shorts casual outdoor'},
    {'original_name': '60002.JPG', 'category': 'Jackets', 'color': 'Brown', 'description': 'Brown jacket urban street setting'},
    {'original_name': '60013.JPEG', 'category': 'Track Pants', 'color': 'Black', 'description': 'Black UNIQLO Ultra Stretch DRY-EX Jogger Pants side view'},
    {'original_name': '60017.JPEG', 'category': 'Sweaters', 'color': 'Beige', 'description': 'Beige HLA Henley Sweater outdoor rooftop'},
    {'original_name': '60019.JPEG', 'category': 'Track Pants', 'color': 'Grey', 'description': 'Grey UNIQLO Ultra Stretch DRY-EX Jogger Pants front view'},
    {'original_name': '60020.JPEG', 'category': 'Tshirts', 'color': 'Red', 'description': 'Manchester United 23/24 Home jersey on hanger'},
    
    # === BATCH 3: Third set of images ===
    {'original_name': '60024.JPEG', 'category': 'Tshirts', 'color': 'Olive', 'description': 'UNIQLO Olive green henley shirt full body'},
    {'original_name': '60022.JPEG', 'category': 'Waistcoat', 'color': 'Black', 'description': 'Black formal vest on hanger'},
    {'original_name': '60029.JPEG', 'category': 'Waistcoat', 'color': 'Black', 'description': 'Black vest worn with shirt'},
    {'original_name': '60023.JPEG', 'category': 'Shirts', 'color': 'White', 'description': 'White UNIQLO non-iron shirt on hanger'},
    {'original_name': '60027.JPEG', 'category': 'Trousers', 'color': 'Beige', 'description': 'Beige MANFINITY Men Solid Tailored Pants worn'},
    {'original_name': '60026.JPEG', 'category': 'Sweatshirts', 'color': 'Black', 'description': 'Black NERDY Blank Logo hoodie full body'},
    {'original_name': '60028.JPEG', 'category': 'Shirts', 'color': 'Blue', 'description': 'Tommy Hilfiger Blue striped button-down shirt THFLEX Regular Fit'},
    {'original_name': '60025.JPEG', 'category': 'Sweatshirts', 'color': 'Black', 'description': 'Black NERDY Blank Logo hoodie close-up'},
    {'original_name': '60021.JPEG', 'category': 'Blazers', 'color': 'Navy Blue', 'description': 'Navy blue UNIQLO comfort jacket on hanger'},
    {'original_name': '60030.JPEG', 'category': 'Trousers', 'color': 'Navy Blue', 'description': 'Navy formal UNIQLO Easy Work Pants'},
    
    # === BATCH 4: Fourth set of images ===
    {'original_name': '60033.JPEG', 'category': 'Shirts', 'color': 'Blue', 'description': 'UNIQLO non-iron blue shirt close-up'},
    {'original_name': '60034.JPEG', 'category': 'Shirts', 'color': 'Grey', 'description': 'UNIQLO non-iron grey shirt close-up'},
    {'original_name': '60036.JPEG', 'category': 'Belts', 'color': 'Brown', 'description': 'UNIQLO men Italian oiled leather belt close-up'},
    {'original_name': '60032.JPEG', 'category': 'Blazers', 'color': 'Navy Blue', 'description': 'Navy blue UNIQLO comfort jacket close-up'},
    {'original_name': '60031.JPEG', 'category': 'Blazers', 'color': 'Navy Blue', 'description': 'Navy blue UNIQLO comfort jacket full body'},
]

# ============================================================================
# GENERATE CSV FILES - FIXED TO USE ACTUAL IDs FROM FILENAMES
# ============================================================================

def generate_csvs():
    """
    Generate styles.csv and images.csv for personal photos
    Uses actual IDs from filenames (not sequential)
    """
    
    styles_entries = []
    images_entries = []
    
    for idx, photo in enumerate(personal_photos_data):
        # EXTRACT ID FROM FILENAME! (e.g., "60003" from "60003.JPEG")
        photo_id = int(photo['original_name'].split('.')[0])
        
        # Determine gender
        gender = 'Men' if 'dad' in photo['description'].lower() else 'Unisex'
        
        # Map category to masterCategory and subCategory
        category_map = {
            'Shirts': {'master': 'Apparel', 'sub': 'Topwear'},
            'Tshirts': {'master': 'Apparel', 'sub': 'Topwear'},
            'Jackets': {'master': 'Apparel', 'sub': 'Topwear'},
            'Blazers': {'master': 'Apparel', 'sub': 'Topwear'},
            'Sweatshirts': {'master': 'Apparel', 'sub': 'Topwear'},
            'Sweaters': {'master': 'Apparel', 'sub': 'Topwear'},
            'Waistcoat': {'master': 'Apparel', 'sub': 'Topwear'},
            'Jeans': {'master': 'Apparel', 'sub': 'Bottomwear'},
            'Trousers': {'master': 'Apparel', 'sub': 'Bottomwear'},
            'Shorts': {'master': 'Apparel', 'sub': 'Bottomwear'},
            'Track Pants': {'master': 'Apparel', 'sub': 'Bottomwear'},
            'Casual Shoes': {'master': 'Footwear', 'sub': 'Shoes'},
            'Belts': {'master': 'Accessories', 'sub': 'Accessories'},
        }
        
        cat_info = category_map[photo['category']]
        
        # styles.csv entry - USE EXTRACTED ID!
        styles_entry = {
            'id': photo_id,  # NOW USES ACTUAL ID FROM FILENAME!
            'gender': gender,
            'masterCategory': cat_info['master'],
            'subCategory': cat_info['sub'],
            'articleType': photo['category'],
            'baseColour': photo['color'],
            'season': 'All',
            'year': 2025,
            'usage': 'Casual',
            'productDisplayName': photo['description']
        }
        styles_entries.append(styles_entry)
        
        # images.csv entry - preserve original extension
        file_ext = photo['original_name'].split('.')[-1]
        images_entry = {
            'filename': f"{photo_id}.{file_ext}",  # Uses actual ID too!
            'link': ''
        }
        images_entries.append(images_entry)
    
    # Create DataFrames
    styles_df = pd.DataFrame(styles_entries)
    images_df = pd.DataFrame(images_entries)
    
    # SORT BY ID! (to keep them in order)
    styles_df = styles_df.sort_values('id').reset_index(drop=True)
    images_df = images_df.sort_values('filename').reset_index(drop=True)
    
    # Save to CSV
    styles_df.to_csv('my_personal_styles.csv', index=False)
    images_df.to_csv('my_personal_images.csv', index=False)
    
    print("✅ Generated CSVs!")
    print(f"\n📊 Summary:")
    print(f"   Total images: {len(styles_entries)}")
    print(f"   ID range: {styles_df['id'].min()} to {styles_df['id'].max()}")
    print(f"   IDs used: {sorted(styles_df['id'].tolist())}")
    print(f"\n📁 Files created:")
    print(f"   - my_personal_styles.csv")
    print(f"   - my_personal_images.csv")
    
    # Print category breakdown
    print(f"\n📋 Category Breakdown:")
    category_counts = styles_df['articleType'].value_counts()
    for cat, count in category_counts.items():
        print(f"   {cat:15s}: {count:>2} images")
    
    return styles_df, images_df

# Run the generator
print("🎉 GENERATING PERSONAL PHOTO METADATA")
print("="*70)
styles_df, images_df = generate_csvs()

# Display organized preview
print("\n" + "="*70)
print("PREVIEW OF GENERATED DATA (sorted by ID):")
print("="*70)
print("\nstyles.csv (first 10 rows):")
print(styles_df.head(10))
print("\nstyles.csv (last 5 rows):")
print(styles_df.tail())
print("\nimages.csv (first 10 rows):")
print(images_df.head(10))
# Out:
# 🎉 GENERATING PERSONAL PHOTO METADATA
# ...
# ✅ Generated CSVs!
#
# 📊 Summary:
#    Total images: 34
#    ID range: 60001 to 60036
#    IDs used: [60001, 60002, 60003, 60004, 60005, 60006, 60007, 60008, 60009, 60010, 60011, 60013, 60014, 60015, 60016, 60017, 60018, 60019, 60020, 60021, 60022, 60023, 60024, 60025, 60026, 60027, 60028, 60029, 60030, 60031, 60032, 60033, 60034, 60036]
#
# 📁 Files created:
#    - my_personal_styles.csv
#    - my_personal_images.csv
#
# 📋 Category Breakdown:
#    Shirts         :  8 images
#    Tshirts        :  4 images
#    Jackets        :  3 images
#    Trousers       :  3 images
#    Blazers        :  3 images
#    Sweatshirts    :  3 images
#    Jeans          :  2 images
#    Track Pants    :  2 images
#    Waistcoat      :  2 images
#    Sweaters       :  1 images
#    Casual Shoes   :  1 images
#    Shorts         :  1 images
#    Belts          :  1 images
#
# ...
# PREVIEW OF GENERATED DATA (sorted by ID):
# ...
#
# styles.csv (first 10 rows):
# ...
